# %%
'''we have dictionary data type we full it information we have code called 
(clinic _helper ) with while loop in side it to process the information so dictionary key The key dictionary 
represents the user and the value represents the chat bot In a sentence while there are two variables, 
the first variable takes the values given by the user and places them in a variable and converts them to a 
list The last variable is 1 where the values of the key are placed after being converted from a 
string and then the values interfere with the existing condition sentences and compares the values 
taken from the user whether they match the values in the lists and then returns them.
Closing sentence of the word bye.'''


import re


print("Hello to May medical chatbot advisor.")
print("I am a chatbot created by May.")
print("You can ask me general question about your health, to get the right advice, please provide me with the critical symptoms.")

clinic={"hi":"hello, how are you?","hello":"hi, how are you?","morning":"Nice morning, how are you?",
          "hey":"hello, how are you?",
          "evening":"Nice night,how are you?","salam":"Wa allekom Alsalam, how are you ?",
          "fine":"I hope you always good",
          "not fine":"Oh no!, you will be good after speaking with me",
         "good":"I hope you always good","not good":"Oh no!, you will be good after speaking with me ",
          "question":" Ok what is your question, I am here to ansewr it !",
          "stomach":" I think you have eaten ready foods at night, if you have not, type :healhty foods",
          "healthy food":" The most common case to get stomach pain is to take anti pain medication like profen, If you have not take profen type:profen_not",
          "profen_not":"You need to see your doctor, can I help you in something else",
          "headache":"drinking a lot of coffee cause headache, type : coffee_not if you do not drink alot",
          "coffee_not":"not sleeping good at night cause headache, type:good_sleep if you slept well",
          "good_sleep":"stress or fear cause headache, if no: type stress_notexist",
          "stress_notexist":"you need to see your doctor if you are not getting rid of during the next 5 days",
          "cold":"you should drink hot drinks with honey, if you do not feel better take medication",
          "yellow":"if your eyes is yellow, you should consult your doctor quickly",
          "back":"if you got a back pain, you should take a rest for few days, consult your doctor if the pain has not got a way",
          "cough":" Is it wet or dried ",
          "wet":" this is virus-based cough,take a rest for one week",
          "dried":"this is a bactiria-based cough, take anti-biotic medications",
          "itching":"this may caused by liver disease, see your doctor quickly",
          "spams":" spams caused either by excess coffee intake or by b12 deficiency",
          "finger":"many times a pain in your finger, especially foot finger is caused by gout disease",
          "hair":" hair lossing or drying hair is caused by iron deficiency",
          "fast":" fast breath is caused by either b12 deciciency or iron deciciency ",
          "diarrhea":"many times diarrhea is caused by un-healthy foods ",
          "consiptation":"most of the times consiptation is caused by not drinking a lot of water",
          
         "bad":"Oh no!, you will be good after speaking with me","ok":"I am here to answer you about your health, so let us start, Are you male or female?",
         "ok thanks":"I am here to answer you about your health, so let us start, Are you male or female?",
          "thanks":"I am here to answer you about your health, so let us start, Are you male or female?",
          "thank you":"I am here to answer you about your health, so let us start, Are you male or female?",
         "male":"Ok, Are you married or not ?","female":"Ok, Are you married or not?",
          "married":"Ok, are you smoking or drinking","I am married":"choose on of the following habits that describe your daily routines: smooking,drinking alcohol,not smoking,not drinking,both not",
          "smoking":" so do you have chest pain?","yes":"mm, choose the word that describe you when you cough: blood or no blood",
          "blood":"I think you need an x-ray for your chest",
          "no blood":"choose how many times you caugh per hours: 3 ,7 ?",
          "3":"Please stop smoking","7":"I think you need an x-ray for your chest",
          "drinking alcohol":"choose the position of the pain: right, left",
          "right":"it is your liver, you need to do a CT-scan"
          
          }
def clinic_helper():

 while True:
    you = input('You:')
    m=you
    if you.strip()!= 'Bye':
      you = re.sub("[^\w]", " ",  you).split()
      greeting_keys=str(clinic.keys())
     
     
      message1 = re.sub("[^\w]", " ",  greeting_keys).split()
    
    
      if m in clinic:
       x = clinic.get(m)
      else:
     
       for i in you:
        if i in message1 and i in you:
         x = clinic.get(i)

        
            
      print('May_ChatBot:',x)
    else:
     print('May_ChatBot:Bye')
     break

clinic_helper()
# Out:
# Hello to May medical chatbot advisor.
# I am a chatbot created by May.
# You can ask me general question about your health, to get the right advice, please provide me with the critical symptoms.
# You:Bye
# May_ChatBot:Bye
