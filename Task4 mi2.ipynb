# %%
import csv
a='good' ##q1
b='fun'
c='great'
import csv
import csv
from collections import defaultdict

columns = defaultdict(list)
c1=0
c2=0
c3=0
with open('short_movies.csv') as f:
    reader = csv.DictReader(f)
    for row in reader:
        for (k,v) in row.items():
            columns[k].append(v) 
list1=[]
for val in columns['text']:
 if a in val:
  c1+=1
 if b in val:
  c2+=1
 if c in val:
  c3+=1
list1.append(c1)
list1.append(c2)
list1.append(c3)
print(list1)
list2=[]
a='bad'
b='sad'
c='suck'
c3=0
c4=0
c5=0
for val in columns['text']:
 if a in val:
  c3+=1
 if b in val:
  c4+=1
 if c in val:
  c5+=1
list2.append(c3)
list2.append(c4)
list2.append(c5)
print(list2)
# Out:
# [784, 553, 580]
# [242, 103, 28]

# %%
re=0
for val in columns['html']:
    val=int(val)
    if val>re:
        re=val
print("The biggest number of reviews is : ",re)
c6=0
a='?'
for val in columns['text']:
 if a in val:
  c6+=1
print(c6)

for val in columns['text']:
 if a in val:
    print(val)
# Out:
# The biggest number of reviews is :  29856
# 895
# getting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that's set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ?
# in the comic , they don't bother cloaking the identity of the ripper , but screenwriters terry hayes ( vertical limit ) and rafael yglesias ( les mis ? rables ) do a good job of keeping him hidden from viewers until the very end .
# and from hell's ending had me whistling the stonecutters song from the simpsons for days ( " who holds back the electric car/who made steve guttenberg a star ? " ) .
# did anybody know this film existed a week before it opened ?
# what happened ?
# ...
